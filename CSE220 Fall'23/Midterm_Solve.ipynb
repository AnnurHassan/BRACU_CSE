# %% [markdown]
# # Spring' 23

# %%
# Question 1
import numpy as np

def multiple_repeat(arr):
    freq = np.array([0] * len(arr))
    rem = np.array([0] * len(arr))
    for i in range(len(arr)):
        count = 0
        for j in range(i, len(arr)):
            if arr[i] not in rem:
                if arr[i] == arr[j]:
                    count += 1
        freq[i] = count
        rem[i] = arr[i]

    for i in range(len(freq)):
        if freq[i] > 1:
            for j in range(i + 1, len(freq)):
                if freq[i] == freq[j]:
                    return True
        
    return False

print("///  Test 01: Protecc Salami  ///")
arr = np.array([4,5,6,6,4,3,6,4])
returned_value = multiple_repeat(arr)
print(f'Task 5: {returned_value}') # This should print True

print("///  Test 02: Protecc Salami  ///")
arr = np.array([3,4,6,3,4,7,4,6,8,6, 6])
returned_value = multiple_repeat(arr)
print(f'Task 5: {returned_value}') # This should print False
# Out:
# ///  Test 01: Protecc Salami  ///
# Task 5: True
# ///  Test 02: Protecc Salami  ///
# Task 5: False

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next


def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head


def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %%
# Question 2

def remove_from_last(head, n):
    temp = head
    total_nodes = countNodes(head)
    index = total_nodes - n
    count = 0
    rem = None
    while temp != None:
        if count == index:
            rem.next = temp.next
            temp.next = None
        
        count += 1
        rem = temp
        temp = temp.next
        
    return head

def countNodes(head):
    temp = head
    count = 0
    while temp != None:
        count += 1
        temp = temp.next
    
    return count

print('==============Test Case 1=============')
head = createList([10, 20, 5, 15, 25])
print('Original Linked List: ', end = ' ')
printLinkedList(head)
returned_value = remove_from_last(head, 2)
print("Modified Linled List: ", end = " ")
printLinkedList(returned_value)

print('==============Test Case 2=============')
head = createList([10, 20, 5, 15, 25])
print('Original Linked List: ', end = ' ')
printLinkedList(head)
returned_value = remove_from_last(head, 8)
print("Modified Linled List: ", end = " ")
printLinkedList(returned_value)
# Out:
# ==============Test Case 1=============
# Original Linked List:  10-->20-->5-->15-->25
#
# Modified Linled List:  10-->20-->5-->25
#
# ==============Test Case 2=============
# Original Linked List:  10-->20-->5-->15-->25
#
# Modified Linled List:  10-->20-->5-->15-->25

# %%
# Run This Cell

class Node:
    def __init__(self,elem=None,next=None):
        self.elem = elem
        self.next = next

class Stack:
    def __init__(self):
        self.__top = None


    def push(self,elem):
        if self.__top == None:
            self.__top = Node(elem, None)
        
        else:
            newNode = Node(elem, None)
            newNode.next = self.__top
            self.__top = newNode


    def pop(self):
        if self.__top == None:
            return None
        
        else:
            popped = self.__top
            self.__top = self.__top.next
            popped.next = None
            return popped.elem

    def peek(self):
        if self.__top == None:
            return None
        
        else:
            return self.__top.elem


    def isEmpty(self):
        if self.__top == None:
            return True
        
        else:
            return False

# %%
# Question 3

def diamond_count(stack,string):
    count = 0
    for i in string:
        if i == "<":
            stack.push(i)
        
        if i == ">":
            popped = stack.pop()
            if popped == "<":
                count += 1

    return count
    

print('Test 01')
stack = Stack()
string = '<..><.<..>> '
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
print('-----------------------------------------')
print('Test 02')
stack = Stack()
string = '<<<..<......<<<<....>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 1
print('-----------------------------------------')
print('Test 03')
stack = Stack()
string = '>>><...<<..>>...>...>>>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3

print('-----------------------------------------')
# Out:
# Test 01
# Number of Diamonds: 3
# -----------------------------------------
# Test 02
# Number of Diamonds: 1
# -----------------------------------------
# Test 03
# Number of Diamonds: 3
# -----------------------------------------

# %% [markdown]
# # Summer' 23

# %%
import numpy as np

# %%
# Question 1

def row_max_min(arr):
    row = len(arr)
    col = len(arr[0])
    new_arr = np.array([0] * row)
    for i in range(row):
        max = 0

        for j in range(col):
            if arr[i][j] > max:
                max = arr[i][j]

        new_arr[i] = max
    
    min = new_arr[0]
    for i in range(len(new_arr)):
        if new_arr[i] < min:
            min = new_arr[i]

    return max

arr = [[2, 7, 5], [9, 3, 8], [1, 4, 6]]
print(row_max_min(arr))

arr = [[2, 7, 5, 10], [9, 3, 8, 4]]
print(row_max_min(arr))
# Out:
# 6
# 9

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next


def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head


def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %%
# Question 2

def is_sorted_asc(head):
    temp = head
    while temp.next != None:
        if temp.elem > temp.next.elem:
            return False
        
        temp = temp.next
        
    return True

print('==============Test Case 1=============')
head = createList([10, 20, 5, 15, 25])
print(is_sorted_asc(head))

print('==============Test Case 2=============')
head = createList([10, 20, 30, 35, 45])
print(is_sorted_asc(head))
# Out:
# ==============Test Case 1=============
# False
# ==============Test Case 2=============
# True

# %%
class Node:
    def __init__(self,elem=None,next=None):
        self.elem = elem
        self.next = next

class Stack:
    def __init__(self):
        self.__top = None


    def push(self,elem):
        if self.__top == None:
            self.__top = Node(elem, None)
        
        else:
            newNode = Node(elem, None)
            newNode.next = self.__top
            self.__top = newNode


    def pop(self):
        if self.__top == None:
            return None
        
        else:
            popped = self.__top
            self.__top = self.__top.next
            popped.next = None
            return popped.elem

    def peek(self):
        if self.__top == None:
            return None
        
        else:
            return self.__top.elem


    def isEmpty(self):
        if self.__top == None:
            return True
        
        else:
            return False

# %%
def print_stack(st):
  if st.isEmpty():
    return
  p = st.pop()
  print('|',p,end=' ')
  if p<10:
    print(' |')
  else:
    print('|')
  #print('------')
  print_stack(st)
  st.push(p)

st = Stack()
st.push(4)
st.push(3)
st.push(5)
st.push(1)
st.push(9)
print_stack(st)
print('------')
# Out:
# | 9  |
# | 1  |
# | 5  |
# | 3  |
# | 4  |
# ------
