# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
    if root:
        rem = root.left
        root.left = root.right
        root.right = rem
        convert_mirror(root.left)
        convert_mirror(root.right)

    return root

# DRIVER CODE

root = BTNode(10)

n1 = BTNode(20)

n2 = BTNode(30)

n3 = BTNode(40)

n4 = BTNode(60)


root.left = n1

root.right = n2


n1.left = n3

n1.right = n4


print("Given Tree Inorder Traversal: ", end=" ")
inorder(root)  # Given Tree Inorder Traversal:  40 20 60 10 30

print()


root2 = convert_mirror(root)

print("Mirrored Tree Inorder Traversal: ", end=" ")

inorder(root2)  # Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def smallest_level(root, level = 0, dict = {}):
    if not(root):
        return 
    
    if level not in dict:
        dict[level] = 99999999
    
    if dict[level] > root.elem:
        dict[level] = root.elem
    
    smallest_level(root.left, level + 1)
    smallest_level(root.right, level + 1)

    return dict

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def inorder_predecessor(root, x):
    if x.left:
        return rightmostnode(x.left)
    
    else:
        pred = None
        while root:
            if x.elem < root.elem:
               root = root.left

            elif x.elem > root.elem:
                pred = root
                root = root.right
            
            else:
                return pred
    
    
def rightmostnode(node):
    while node.right:
        node = node.right
    
    return node
    

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14

x = root.left
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 8: 4
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14
# Inorder predecessor of node 8: 4

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):
    if not root:
        return 
    
    if (x.left == y) or (x.right == y):
        return x.elem
    
    if (y.left == x) or (y.right == x):
        return y.elem
    
    if x.elem < root.elem and y.elem < root.elem:
        return LCA(root.left, x, y)
    
    if x.elem > root.elem and y.elem > root.elem:
        return LCA(root.right, x, y)


    return root.elem

#DRIVER CODE
root = BTNode(15)
n1 = BTNode(10)
n2 = BTNode(25)
n3 = BTNode(8)
n4 = BTNode(12)
n5 = BTNode(20)
n6 = BTNode(30)
n7 = BTNode(6)
n8 = BTNode(9)
n9 = BTNode(18)
n10 = BTNode(22)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n2.left = n5
n2.right = n6

n3.left = n7
n3.right = n8

n5.left = n9
n5.right = n10


print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()

x, y = n7, n4
print(f"LCA({x.elem},{y.elem}) = {LCA(root, x, y)}")

x, y = n5, n7
print(f"LCA({x.elem},{y.elem}) = {LCA(root, x, y)}")

x, y = n9, n10
print(f"LCA({x.elem},{y.elem}) = {LCA(root, x, y)}")

x, y = n5, n2
print(f"LCA({x.elem},{y.elem}) = {LCA(root, x, y)}")

x, y = n1, n4
print(f"LCA({x.elem},{y.elem}) = {LCA(root, x, y)}")
# Out:
# Given Tree Inorder Traversal:  6 8 9 10 12 15 18 20 22 25 30
# LCA(6,12) = 10
# LCA(20,6) = 15
# LCA(18,22) = 20
# LCA(20,25) = 25
# LCA(10,12) = 10
# LCA(18,25) = 25

# %% [markdown]
# BONUS TASK 1

# %%
#WRITE THE FUNCTION and DRIVER CODE BY YOURSELF

def sumTree(root):
    sum = sumSubTree(root) - root.elem
    if sum == root.elem:
        return True

    else:
        False
        
def sumSubTree(root): 
    if not root:
        return 0
    
    sum = root.elem + sumSubTree(root.left) + sumSubTree(root.right)

    return sum

root = BTNode(26)
n2 = BTNode(10)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(6)
n6 = BTNode(3)

root.left = n2
root.right = n3

n2.left = n4
n2.right = n5

n3.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()

print(sumTree(root))
# Out:
# Given Tree Inorder Traversal:  4 10 6 26 3 3
# True

# %% [markdown]
# Bonus Task 2

# %%
#WRITE THE FUNCTION BY YOURSELF
def differnce(root, level = 0, diff = 0):
    if not(root):
        return diff
    
    if level % 2 == 0:
        diff -= root.elem

    else:
        diff += root.elem
    
    diff = differnce(root.left, level + 1, diff)
    diff = differnce(root.right, level + 1, diff)

    return diff

#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)

root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()

print(differnce(root))
# Out:
# Given Tree Inorder Traversal:  4 2 1 7 5 8 3 6
# 4
